# %%
using ITensors
using Plots
using Measurements

# %%
L = 20;
N = 1;
G² = 1.5;
m = 0.4;

# %%
sites = siteinds("Fermion", L);
ITensors.state(::StateName"Plus", ::SiteType"Fermion") = [1/sqrt(2) 1/sqrt(2)]

# %%
function GrossNeveu(l)
    ampo = OpSum();
    for j in 1:l-N
        ampo -= 1im,"C",j,"Cdag",j+N
        ampo += 1im,"C",j+N,"Cdag",j
    end
    for j in 1:N:l-N
        ampo += (G²/2),"C * Cdag",j
    end
    for j in 1:l
        ampo += (m*(-1)^j),"C * Cdag",j
    end
    ψ₀ = randomMPS(sites[1:l],10)
    H = MPO(ampo, sites[1:l])
    sweep = Sweeps([
         "maxdim" "mindim" "cutoff" 
          100      2       1e-16    
          300      10      1e-16    
          700      20      1e-18    
          1000     30      1e-20    
          1024     50      1e-22
         ])
    e, ψ = dmrg(H, ψ₀, sweep)
    return e,ψ,H
end
# Out:
# GrossNeveu (generic function with 1 method)

# %%
mps_vector = Vector{MPS}()
mpo_vector = Vector{MPO}()
ovr_vector = Vector{Float64}()
for j in 2:2:L
    println("j = ",j)
    e₀, ψ₀, H = GrossNeveu(j)
    nrm = norm(inner(H,ψ₀,H,ψ₀) - inner(ψ₀',H,ψ₀)^2)
    push!(mps_vector, ψ₀)
    push!(mpo_vector, H)
    push!(ovr_vector,nrm)
end
# Out:
# j = 2
# After sweep 1 energy=-0.625312359163 maxlinkdim=2 maxerr=0.00E+00 time=26.968
# After sweep 2 energy=-0.625312451187 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 3 energy=-0.625312451187 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 4 energy=-0.625312451187 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 5 energy=-0.625312451187 maxlinkdim=2 maxerr=0.00E+00 time=0.025
# j = 4
# After sweep 1 energy=-1.129623387940 maxlinkdim=4 maxerr=0.00E+00 time=25.038
# After sweep 2 energy=-1.173074147171 maxlinkdim=4 maxerr=0.00E+00 time=0.004
# After sweep 3 energy=-1.175029904835 maxlinkdim=4 maxerr=0.00E+00 time=0.003
# After sweep 4 energy=-1.175096451009 maxlinkdim=4 maxerr=0.00E+00 time=0.003
# After sweep 5 energy=-1.175098692496 maxlinkdim=4 maxerr=0.00E+00 time=0.005
# j = 6
# After sweep 1 energy=-1.820901897265 maxlinkdim=8 maxerr=0.00E+00 time=0.005
# After sweep 2 energy=-1.828435470870 maxlinkdim=8 maxerr=0.00E+00 time=0.008
# After sweep 3 energy=-1.829812745970 maxlinkdim=8 maxerr=0.00E+00 time=0.007
# After sweep 4 energy=-1.830033995941 maxlinkdim=8 maxerr=0.00E+00 time=0.009
# After sweep 5 energy=-1.830064764725 maxlinkdim=8 maxerr=0.00E+00 time=0.007
# j = 8
# After sweep 1 energy=-2.530668053145 maxlinkdim=16 maxerr=0.00E+00 time=0.013
# After sweep 2 energy=-2.535723348768 maxlinkdim=16 maxerr=0.00E+00 time=0.014
# After sweep 3 energy=-2.535755120805 maxlinkdim=16 maxerr=0.00E+00 time=0.015
# After sweep 4 energy=-2.535755159214 maxlinkdim=16 maxerr=0.00E+00 time=0.015
# After sweep 5 energy=-2.535755159231 maxlinkdim=16 maxerr=0.00E+00 time=0.019
# j = 10
# After sweep 1 energy=-3.199856749868 maxlinkdim=32 maxerr=0.00E+00 time=0.031
# After sweep 2 energy=-3.200806789583 maxlinkdim=32 maxerr=0.00E+00 time=0.035
# After sweep 3 energy=-3.200807271577 maxlinkdim=32 maxerr=0.00E+00 time=0.061
# After sweep 4 energy=-3.200807271579 maxlinkdim=30 maxerr=4.83E-22 time=0.021
# After sweep 5 energy=-3.200807271579 maxlinkdim=32 maxerr=0.00E+00 time=0.025
# j = 12
# After sweep 1 energy=-3.803447063937 maxlinkdim=40 maxerr=0.00E+00 time=0.042
# After sweep 2 energy=-3.844200681877 maxlinkdim=64 maxerr=0.00E+00 time=0.088
# After sweep 3 energy=-3.845306632920 maxlinkdim=64 maxerr=0.00E+00 time=0.044
# After sweep 4 energy=-3.845308450252 maxlinkdim=64 maxerr=0.00E+00 time=0.071
# After sweep 5 energy=-3.845308450571 maxlinkdim=64 maxerr=0.00E+00 time=0.043
# j = 14
# After sweep 1 energy=-4.456343936185 maxlinkdim=40 maxerr=0.00E+00 time=0.057
# After sweep 2 energy=-4.467548881196 maxlinkdim=124 maxerr=6.91E-17 time=0.131
# After sweep 3 energy=-4.474399503006 maxlinkdim=128 maxerr=0.00E+00 time=0.158
# After sweep 4 energy=-4.477636233119 maxlinkdim=128 maxerr=0.00E+00 time=0.147
# After sweep 5 energy=-4.478356366135 maxlinkdim=128 maxerr=0.00E+00 time=0.161
# j = 16
# After sweep 1 energy=-5.121604917807 maxlinkdim=40 maxerr=0.00E+00 time=0.040
# After sweep 2 energy=-5.136404156953 maxlinkdim=158 maxerr=7.79E-17 time=0.266
# After sweep 3 energy=-5.138175821471 maxlinkdim=252 maxerr=9.69E-19 time=0.621
# After sweep 4 energy=-5.138886730735 maxlinkdim=256 maxerr=0.00E+00 time=0.664
# After sweep 5 energy=-5.139115162412 maxlinkdim=256 maxerr=0.00E+00 time=0.617
# j = 18
# After sweep 1 energy=-5.783000966612 maxlinkdim=40 maxerr=0.00E+00 time=0.057
# After sweep 2 energy=-5.810140412614 maxlinkdim=160 maxerr=0.00E+00 time=0.445
# After sweep 3 energy=-5.812884275690 maxlinkdim=460 maxerr=9.70E-19 time=2.954
# After sweep 4 energy=-5.813123901953 maxlinkdim=504 maxerr=8.52E-21 time=3.664
# After sweep 5 energy=-5.813137792883 maxlinkdim=508 maxerr=7.25E-23 time=3.867
# j = 20
# After sweep 1 energy=-6.414172488880 maxlinkdim=40 maxerr=0.00E+00 time=0.086
# After sweep 2 energy=-6.470569426421 maxlinkdim=160 maxerr=0.00E+00 time=0.582
# After sweep 3 energy=-6.472947575083 maxlinkdim=526 maxerr=9.67E-19 time=7.331
# After sweep 4 energy=-6.472965236048 maxlinkdim=676 maxerr=9.96E-21 time=17.230
# After sweep 5 energy=-6.472965346617 maxlinkdim=686 maxerr=9.95E-23 time=18.640

# %%
for j in 1:length(mps_vector)
    println(inds(mps_vector[j][end-1])[1])
end
# Out:
# (dim=2|id=636|"Fermion,Site,n=1")
# (dim=2|id=282|"Fermion,Site,n=3")
# (dim=2|id=16|"Fermion,Site,n=5")
# (dim=2|id=978|"Fermion,Site,n=7")
# (dim=2|id=864|"Fermion,Site,n=9")
# (dim=2|id=561|"Fermion,Site,n=11")
# (dim=2|id=166|"Fermion,Site,n=13")
# (dim=2|id=395|"Fermion,Site,n=15")
# (dim=2|id=406|"Fermion,Site,n=17")
# (dim=2|id=324|"Fermion,Site,n=19")

# %%
function OverLap(ψ₁::MPS, ψ₂::MPS)
    len₁ = length(ψ₁)
    len₂ = length(ψ₂)  # larger lattice
    v = ITensor(1.0)
    v1 = state(inds(ψ₂[len₂-1])[1], "Plus")
    v2 = state(inds(ψ₂[len₂])[1], "Plus")
    for j in 1:len₁
        v = v*dag(ψ₁[j])*ψ₂[j]
    end
    v = v*dag(v1)*ψ₂[len₂-1]
    v = v*dag(v2)*ψ₂[len₂]
    return inner(v,v), norm(v)
end
# Out:
# OverLap (generic function with 1 method)

# %%
ol_inner = Vector{Float64}()
ol_norm = Vector{Float64}()
for j in 1:(length(mps_vector)-1)
    inn, nrm = OverLap(mps_vector[j],mps_vector[j+1])
    push!(ol_inner, inn)
    push!(ol_norm, nrm)
end

# %%
err = [sqrt(x) for x in ovr_vector[1:end-1]];
print(length(err))
minimum(err), maximum(err)
# Out:
# 9
# (7.450617676733326e-9, 0.008671767409672279)

# %%
x = [x for x in 1:length(ol_norm)]
scatter(x,ol_norm .±err*2,
#     xlim=(-1,40),xticks=((1:2:40)), 
#     ylim=(0.1,0.9), 
    #yticks=((0.4:0.01:0.5)),   
    markersize=2,
    xlabel="Site Number",
    ylabel="Inner Product",
    title="Overlap")
#savefig("one_norm_err.svg")

# %%
ol_norm
# Out:
# 9-element Vector{Float64}:
#  0.46962830943137696
#  0.18724483332480968
#  0.45132114593225114
#  0.45594003779616465
#  0.4582296384480542
#  0.45428567047046653
#  0.12246001070031151
#  0.4504064488870521
#  0.4492598565497108
